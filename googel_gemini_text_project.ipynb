# %%
# %pip install -U -q "google-generativeai>=1.0.0"
# Out:
# ERROR: Ignored the following yanked versions: 0.1.0rc2
# ERROR: Could not find a version that satisfies the requirement google-generativeai>=1.0.0 (from versions: 0.1.0rc1, 0.1.0rc3, 0.1.0, 0.2.0, 0.2.1, 0.2.2, 0.3.0, 0.3.1, 0.3.2, 0.4.0, 0.4.1, 0.5.0, 0.5.1, 0.5.2, 0.5.3, 0.5.4, 0.6.0, 0.7.0, 0.7.1, 0.7.2, 0.8.0, 0.8.1, 0.8.2, 0.8.3, 0.8.4, 0.8.5)
# ERROR: No matching distribution found for google-generativeai>=1.0.0

# %%
import os
import google.generativeai as genai
from IPython.display import Markdown

# %%
API_KEY = "AIzaSyAkSGKS64tWCM.................."
genai.configure(api_key=API_KEY)

# %%
MODEL_ID = "gemini-2.5-flash"

# %%
model = genai.GenerativeModel(model_name=MODEL_ID)

# %%
response = model.generate_content("What's the largest planet in our solar system?")

# ✅ Display response
Markdown(response.text)
# Out:
# The largest planet in our solar system is **Jupiter**.

# %%
import requests
import pathlib
from PIL import Image

IMG = "https://storage.googleapis.com/generativeai-downloads/data/jetpack.png" # @param {type: "string"}

img_bytes = requests.get(IMG).content

img_path = pathlib.Path('jetpack.png')
img_path.write_bytes(img_bytes)
# Out:
# 1567837

# %%
from IPython.display import display, Markdown
image = Image.open(img_path)
image.thumbnail([512,512])

response = client.models.generate_content(
    model=MODEL_ID,
    contents=[
        image,
        "Write a short and engaging blog post based on this picture."
    ]
)

display(image)
Markdown(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-563812047.py in <cell line: 0>()
#       3 image.thumbnail([512,512])
#       4
# ----> 5 response = client.models.generate_content(
#       6     model=MODEL_ID,
#       7     contents=[
#
# NameError: name 'client' is not defined
